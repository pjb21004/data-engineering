# %% [markdown]
# ## <strong>9. RESTful API를 이용한 데이터 취득</strong>

# %%
import requests  # HTTP 통신 라이브러리
import matplotlib.pyplot as plt # 데이터 시각화
import time # API 요청 제한(Rate Limit) 우회를 위한 시간 제어

# %%
# 1. 상위 100개 코인 정보 가져오기 (Data Acquisition 단계)
def get_top_100_coins():
    """
    CoinGecko API를 통해 시장의 원천 데이터(Raw Data)를 취득
    """
    url = "https://api.coingecko.com/api/v3/coins/markets"
    
    # API 요청 파라미터 설정
    params = {
        "vs_currency": "usd",        # 통화 단위: USD
        "order": "market_cap_desc",  # 정렬 기준: 시가총액 내림차순
        "per_page": 100,             # 취득할 데이터 양: 100개
        "page": 1,                   # 페이지 번호
        "sparkline": False           # 데이터 부하를 줄이기 위해 그래프 데이터 제외
    }
    
    # RESTful API 호출 (HTTP GET 방식)
    response = requests.get(url, params=params)
    
    # 응답받은 JSON 데이터를 파이썬 객체로 변환
    return response.json()

# %%
# 2. 특정 코인의 시가총액 추이 가져오기
def get_market_chart(coin_id):
    """
    특정 코인의 ID를 사용하여 시계열 데이터를 요청
    """
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart"
    params = {
        "vs_currency": "usd",
        "days": 365,          # 데이터 범위: 최근 365일
        "interval": "daily"   # 데이터 간격: 일 단위 (데이터 정제 과정)
    }
    
    response = requests.get(url, params=params)
    
    # HTTP 상태 코드가 200(성공)일 경우에만 데이터 반환 (예외 처리)
    if response.status_code == 200:
        return response.json()["market_caps"]
    else:
        # 데이터 취득 실패 시 빈 리스트 반환
        return []

# %%
# 3. 시각화 함수 
def plot_market_caps(coin_data):
    """
    가공된 데이터를 바탕으로 분석용 차트를 생성
    """
    plt.figure(figsize=(16, 10))

    for coin_name, market_caps in coin_data.items():
        if not market_caps:
            continue
            
        timestamps = [cap[0] for cap in market_caps] # x축: 타임스탬프
        
        # 데이터 스케일링: 가독성을 위해 달러 단위를 10억(Billion) 단위로 변환
        values = [cap[1] / 1e9 for cap in market_caps] 
        
        plt.plot(timestamps, values, label=coin_name)

    # 시각화
    plt.title("Top 100 Alt Coins - Market Cap Trend (Last 365 Days)")
    plt.xlabel("Timestamp")
    plt.ylabel("Market Cap (Billion USD)")
    plt.xticks(rotation=45)
    plt.legend(fontsize="small", loc="upper left", ncol=2)
    plt.tight_layout()
    plt.grid(True)
    plt.show()

# %%
# --- 메인 실행 흐름 ---

print("🚀 상위 100개 코인 정보를 불러오는 중...")
all_coins = get_top_100_coins()

# 데이터 필터링: 시장 지배력이 너무 큰 BTC, ETH를 제외하여 주요 알트코인들의 추이를 비교
coins = all_coins[2:] 

coin_market_data = {}

# 반복문을 통한 대량 데이터 취득
for i, coin in enumerate(coins):
    coin_id = coin["id"]
    coin_name = coin["name"]
    
    print(f"📈 데이터 수집 중: {coin_name} ({i+1}/100)")
    market_caps = get_market_chart(coin_id)
    
    # 딕셔너리에 데이터 적재
    coin_market_data[coin_name] = market_caps
    
    # API 요청 제한 우회
    time.sleep(1.2) 

    # 실습 효율을 위해 상위 4개 알트코인만 수집 후 중단
#    if i >= 3: 
#        break
# Out:
# 🚀 상위 100개 코인 정보를 불러오는 중...
# 📈 데이터 수집 중: Tether (1/100)
# 📈 데이터 수집 중: XRP (2/100)
# 📈 데이터 수집 중: BNB (3/100)
# 📈 데이터 수집 중: USDC (4/100)
# 📈 데이터 수집 중: Solana (5/100)
# 📈 데이터 수집 중: TRON (6/100)
# 📈 데이터 수집 중: Figure Heloc (7/100)
# 📈 데이터 수집 중: Dogecoin (8/100)
# 📈 데이터 수집 중: WhiteBIT Coin (9/100)
# 📈 데이터 수집 중: USDS (10/100)
# 📈 데이터 수집 중: Hyperliquid (11/100)
# 📈 데이터 수집 중: LEO Token (12/100)
# 📈 데이터 수집 중: Cardano (13/100)
# 📈 데이터 수집 중: Bitcoin Cash (14/100)
# 📈 데이터 수집 중: Chainlink (15/100)
# 📈 데이터 수집 중: Monero (16/100)
# 📈 데이터 수집 중: Zcash (17/100)
# 📈 데이터 수집 중: Canton (18/100)
# 📈 데이터 수집 중: Ethena USDe (19/100)
# 📈 데이터 수집 중: Stellar (20/100)
# 📈 데이터 수집 중: MemeCore (21/100)
# 📈 데이터 수집 중: Dai (22/100)
# 📈 데이터 수집 중: Litecoin (23/100)
# 📈 데이터 수집 중: USD1 (24/100)
# 📈 데이터 수집 중: Avalanche (25/100)
# 📈 데이터 수집 중: PayPal USD (26/100)
# 📈 데이터 수집 중: Rain (27/100)
# 📈 데이터 수집 중: Hedera (28/100)
# 📈 데이터 수집 중: Sui (29/100)
# 📈 데이터 수집 중: Toncoin (30/100)
# 📈 데이터 수집 중: Shiba Inu (31/100)
# 📈 데이터 수집 중: RaveDAO (32/100)
# 📈 데이터 수집 중: Cronos (33/100)
# 📈 데이터 수집 중: Circle USYC (34/100)
# 📈 데이터 수집 중: Tether Gold (35/100)
# 📈 데이터 수집 중: World Liberty Financial (36/100)
# 📈 데이터 수집 중: BlackRock USD Institutional Digital Liquidity Fund (37/100)
# 📈 데이터 수집 중: Bittensor (38/100)
# 📈 데이터 수집 중: PAX Gold (39/100)
# 📈 데이터 수집 중: Mantle (40/100)
# 📈 데이터 수집 중: Global Dollar (41/100)
# 📈 데이터 수집 중: Uniswap (42/100)
# 📈 데이터 수집 중: Polkadot (43/100)
# 📈 데이터 수집 중: NEAR Protocol (44/100)
# 📈 데이터 수집 중: OKB (45/100)
# 📈 데이터 수집 중: Falcon USD (46/100)
# 📈 데이터 수집 중: Sky (47/100)
# 📈 데이터 수집 중: Pi Network (48/100)
# 📈 데이터 수집 중: Aster (49/100)
# 📈 데이터 수집 중: HTX DAO (50/100)
# 📈 데이터 수집 중: Pepe (51/100)
# 📈 데이터 수집 중: USDD (52/100)
# 📈 데이터 수집 중: Aave (53/100)
# 📈 데이터 수집 중: Ripple USD (54/100)
# 📈 데이터 수집 중: Janus Henderson Anemoy Treasury Fund (55/100)
# 📈 데이터 수집 중: Internet Computer (56/100)
# 📈 데이터 수집 중: Bitget Token (57/100)
# 📈 데이터 수집 중: Ethereum Classic (58/100)
# 📈 데이터 수집 중: Ondo US Dollar Yield (59/100)
# 📈 데이터 수집 중: BFUSD (60/100)
# 📈 데이터 수집 중: Ondo (61/100)
# 📈 데이터 수집 중: KuCoin (62/100)
# 📈 데이터 수집 중: Gate (63/100)
# 📈 데이터 수집 중: Pump.fun (64/100)
# 📈 데이터 수집 중: Quant (65/100)
# 📈 데이터 수집 중: Worldcoin (66/100)
# 📈 데이터 수집 중: Algorand (67/100)
# 📈 데이터 수집 중: Morpho (68/100)
# 📈 데이터 수집 중: Render (69/100)
# 📈 데이터 수집 중: Spiko EU T-Bills Money Market Fund (70/100)
# 📈 데이터 수집 중: NEXO (71/100)
# 📈 데이터 수집 중: POL (ex-MATIC) (72/100)
# 📈 데이터 수집 중: Kaspa (73/100)
# 📈 데이터 수집 중: Cosmos Hub (74/100)
# 📈 데이터 수집 중: USDtb (75/100)
# 📈 데이터 수집 중: Ethena (76/100)
# 📈 데이터 수집 중: Superstate Short Duration U.S. Government Securities Fund (USTB) (77/100)
# 📈 데이터 수집 중: Blockchain Capital (78/100)
# 📈 데이터 수집 중: Aptos (79/100)
# 📈 데이터 수집 중: Filecoin (80/100)
# 📈 데이터 수집 중: Provenance Blockchain (81/100)
# 📈 데이터 수집 중: Flare (82/100)
# 📈 데이터 수집 중: JUST (83/100)
# 📈 데이터 수집 중: Arbitrum (84/100)
# 📈 데이터 수집 중: OUSG (85/100)
# 📈 데이터 수집 중: Official Trump (86/100)
# 📈 데이터 수집 중: XDC Network (87/100)
# 📈 데이터 수집 중: Beldex (88/100)
# 📈 데이터 수집 중: Jupiter (89/100)
# 📈 데이터 수집 중: VeChain (90/100)
# 📈 데이터 수집 중: Midnight (91/100)
# 📈 데이터 수집 중: GHO (92/100)
# 📈 데이터 수집 중: YLDS (93/100)
# 📈 데이터 수집 중: ​​Stable (94/100)
# 📈 데이터 수집 중: Usual USD (95/100)
# 📈 데이터 수집 중: Siren (96/100)
# 📈 데이터 수집 중: Artificial Superintelligence Alliance (97/100)
# 📈 데이터 수집 중: Bonk (98/100)

# %%
# 최종 가공된 데이터를 시각화
plot_market_caps(coin_market_data)

# %%
# get_top_100_coins() 응답 내용(JSON) 확인
coins
# Out:
# [{'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 1.0,
#   'market_cap': 184713170227,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 190181256915,
#   'total_volume': 89420309782,
#   'high_24h': 1.0,
#   'low_24h': 0.999792,
#   'price_change_24h': 0.00017053,
#   'price_change_percentage_24h': 0.01705,
#   'market_cap_change_24h': 267268753,
#   'market_cap_change_percentage_24h': 0.1449,
#   'circulating_supply': 184674430497.4122,
#   'total_supply': 190141370368.7762,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.40218,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.70646,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:13.552Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 617.76,
#   'market_cap': 84212017076,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 84212017076,
#   'total_volume': 1399342715,
#   'high_24h': 617.57,
#   'low_24h': 595.86,
#   'price_change_24h': 21.7,
#   'price_change_percentage_24h': 3.64099,
#   'market_cap_change_24h': 2884103891,
#   'market_cap_change_percentage_24h': 3.54627,
#   'circulating_supply': 136356361.76,
#   'total_supply': 136356361.76,
#   'max_supply': 200000000.0,
#   'ath': 1369.99,
#   'ath_change_percentage': -54.90759,
#   'ath_date': '2025-10-13T08:41:24.131Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1551376.54085,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:12.322Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 1.37,
#   'market_cap': 84079293776,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 136905027432,
#   'total_volume': 2913364007,
#   'high_24h': 1.38,
#   'low_24h': 1.32,
#   'price_change_24h': 0.04380813,
#   'price_change_percentage_24h': 3.30376,
#   'market_cap_change_24h': 2663553083,
#   'market_cap_change_percentage_24h': 3.27155,
#   'circulating_supply': 61405531717.0,
#   'total_supply': 99985687636.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.65,
#   'ath_change_percentage': -62.43346,
#   'ath_date': '2025-07-18T03:40:53.808Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 50894.51515,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:12.703Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602',
#   'current_price': 0.999677,
#   'market_cap': 78731839455,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 78751179360,
#   'total_volume': 18001930844,
#   'high_24h': 1.0,
#   'low_24h': 0.99801,
#   'price_change_24h': -0.000221402325592868,
#   'price_change_percentage_24h': -0.02214,
#   'market_cap_change_24h': 124839496,
#   'market_cap_change_percentage_24h': 0.15881,
#   'circulating_supply': 78754710414.47583,
#   'total_supply': 78774055938.27072,
#   'max_supply': None,
#   'ath': 1.043,
#   'ath_change_percentage': -4.18919,
#   'ath_date': '2018-11-15T00:00:00.000Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.9128,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:13.407Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 86.02,
#   'market_cap': 49464854416,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 53700222128,
#   'total_volume': 4720817298,
#   'high_24h': 86.62,
#   'low_24h': 81.74,
#   'price_change_24h': 4.02,
#   'price_change_percentage_24h': 4.90035,
#   'market_cap_change_24h': 2357752449,
#   'market_cap_change_percentage_24h': 5.00509,
#   'circulating_supply': 575141575.315351,
#   'total_supply': 624387347.0666604,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -70.67432,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 17075.62296,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:12.698Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/photo_2026-04-13_09-59-16.png?1776048311',
#   'current_price': 0.321278,
#   'market_cap': 30452147479,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 30452153731,
#   'total_volume': 516213788,
#   'high_24h': 0.322229,
#   'low_24h': 0.319321,
#   'price_change_24h': -0.000592869444228261,
#   'price_change_percentage_24h': -0.18419,
#   'market_cap_change_24h': -48738447.11981201,
#   'market_cap_change_percentage_24h': -0.15979,
#   'circulating_supply': 94774719771.8855,
#   'total_supply': 94774739231.5531,
#   'max_supply': None,
#   'ath': 0.431288,
#   'ath_change_percentage': -25.50744,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 17705.8153,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 168.0935467255898,
#    'currency': 'usd',
#    'percentage': 16809.35467255898},
#   'last_updated': '2026-04-14T08:30:12.802Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 1.027,
#   'market_cap': 17091614828,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 17091614828,
#   'total_volume': 14802046,
#   'high_24h': 1.03,
#   'low_24h': 1.017,
#   'price_change_24h': 0.007334,
#   'price_change_percentage_24h': 0.71934,
#   'market_cap_change_24h': 122069469,
#   'market_cap_change_percentage_24h': 0.71934,
#   'circulating_supply': 16644323597.827,
#   'total_supply': 16644323597.827,
#   'max_supply': None,
#   'ath': 1.049,
#   'ath_change_percentage': -2.12036,
#   'ath_date': '2026-03-09T17:00:25.937Z',
#   'atl': 0.155357,
#   'atl_change_percentage': 560.97836,
#   'atl_date': '2025-10-31T14:27:24.456Z',
#   'roi': None,
#   'last_updated': '2026-04-14T05:18:27.512Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.093777,
#   'market_cap': 14417223411,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 15889789207,
#   'total_volume': 1634760711,
#   'high_24h': 0.094248,
#   'low_24h': 0.090757,
#   'price_change_24h': 0.00296488,
#   'price_change_percentage_24h': 3.26485,
#   'market_cap_change_24h': 445627913,
#   'market_cap_change_percentage_24h': 3.18953,
#   'circulating_supply': 153824036383.7052,
#   'total_supply': 169535523126.579,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -87.18155,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 107809.00883,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.605Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 54.79,
#   'market_cap': 11694667750,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 17516832733,
#   'total_volume': 80768952,
#   'high_24h': 55.0,
#   'low_24h': 51.87,
#   'price_change_24h': 2.86,
#   'price_change_percentage_24h': 5.51394,
#   'market_cap_change_24h': 612885993,
#   'market_cap_change_percentage_24h': 5.53057,
#   'circulating_supply': 213418274.0,
#   'total_supply': 319668099.0,
#   'max_supply': 400000000.0,
#   'ath': 64.11,
#   'ath_change_percentage': -14.51401,
#   'ath_date': '2025-12-10T20:16:13.582Z',
#   'atl': 3.06,
#   'atl_change_percentage': 1689.90554,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:04.914Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 0.999708,
#   'market_cap': 11321937283,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 11321937283,
#   'total_volume': 85017997,
#   'high_24h': 1.0,
#   'low_24h': 0.999459,
#   'price_change_24h': -0.000115161167597799,
#   'price_change_percentage_24h': -0.01152,
#   'market_cap_change_24h': -181443292.83324814,
#   'market_cap_change_percentage_24h': -1.5773,
#   'circulating_supply': 11325342415.20662,
#   'total_supply': 11325342415.20662,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.22611,
#   'ath_date': '2026-04-02T07:21:14.655Z',
#   'atl': 0.948265,
#   'atl_change_percentage': 5.42537,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.308Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 44.99,
#   'market_cap': 10725912979,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 43296574102,
#   'total_volume': 439812106,
#   'high_24h': 45.0,
#   'low_24h': 41.17,
#   'price_change_24h': 3.77,
#   'price_change_percentage_24h': 9.14975,
#   'market_cap_change_24h': 897337789,
#   'market_cap_change_percentage_24h': 9.12989,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'max_supply': 1000000000.0,
#   'ath': 59.3,
#   'ath_change_percentage': -24.13073,
#   'ath_date': '2025-09-18T03:30:30.650Z',
#   'atl': 3.81,
#   'atl_change_percentage': 1081.3159,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.528Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 10.09,
#   'market_cap': 9292979216,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 9942831643,
#   'total_volume': 568467,
#   'high_24h': 10.16,
#   'low_24h': 10.08,
#   'price_change_24h': -0.015248235385412201,
#   'price_change_percentage_24h': -0.15082,
#   'market_cap_change_24h': -21977840.23608589,
#   'market_cap_change_percentage_24h': -0.23594,
#   'circulating_supply': 920845344.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 10.2,
#   'ath_change_percentage': -1.08859,
#   'ath_date': '2026-04-08T16:00:43.393Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 1160.86214,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.978Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.243117,
#   'market_cap': 8980480457,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 10939838367,
#   'total_volume': 505080868,
#   'high_24h': 0.248701,
#   'low_24h': 0.237778,
#   'price_change_24h': 0.00522019,
#   'price_change_percentage_24h': 2.19431,
#   'market_cap_change_24h': 189645638,
#   'market_cap_change_percentage_24h': 2.15731,
#   'circulating_supply': 36940364839.85039,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -92.12428,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 1162.76268,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:09.270Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 435.81,
#   'market_cap': 8724668584,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 8724671308,
#   'total_volume': 206021511,
#   'high_24h': 439.56,
#   'low_24h': 423.69,
#   'price_change_24h': 11.42,
#   'price_change_percentage_24h': 2.69015,
#   'market_cap_change_24h': 228333058,
#   'market_cap_change_percentage_24h': 2.68743,
#   'circulating_supply': 20020896.77165078,
#   'total_supply': 20020903.02165078,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -88.48829,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 466.47021,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:09.114Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405',
#   'current_price': 9.21,
#   'market_cap': 6691333051,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 9202768976,
#   'total_volume': 448422037,
#   'high_24h': 9.4,
#   'low_24h': 8.7,
#   'price_change_24h': 0.483745,
#   'price_change_percentage_24h': 5.54598,
#   'market_cap_change_24h': 349424500,
#   'market_cap_change_percentage_24h': 5.50977,
#   'circulating_supply': 727099970.4523476,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -82.52976,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 6112.72934,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:09.301Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 347.87,
#   'market_cap': 6417917817,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 6417917817,
#   'total_volume': 104512571,
#   'high_24h': 349.46,
#   'low_24h': 343.29,
#   'price_change_24h': 0.422439,
#   'price_change_percentage_24h': 0.12158,
#   'market_cap_change_24h': 9381200,
#   'market_cap_change_percentage_24h': 0.14639,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 797.73,
#   'ath_change_percentage': -56.39276,
#   'ath_date': '2026-01-14T19:34:07.049Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 160819.35532,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.163Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://coin-images.coingecko.com/coins/images/486/large/circle-zcash-color.png?1696501740',
#   'current_price': 371.07,
#   'market_cap': 6169469456,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 6169753613,
#   'total_volume': 563544857,
#   'high_24h': 381.27,
#   'low_24h': 345.51,
#   'price_change_24h': 10.61,
#   'price_change_percentage_24h': 2.94367,
#   'market_cap_change_24h': 165539016,
#   'market_cap_change_percentage_24h': 2.75718,
#   'circulating_supply': 16656784.5405448,
#   'total_supply': 16657551.7280448,
#   'max_supply': 21000000.0,
#   'ath': 3191.93,
#   'ath_change_percentage': -88.37465,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 16.08,
#   'atl_change_percentage': 2207.6495,
#   'atl_date': '2024-07-05T04:22:29.321Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.624Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'image': 'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299',
#   'current_price': 0.15503,
#   'market_cap': 5925158644,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 5925158644,
#   'total_volume': 26442759,
#   'high_24h': 0.160445,
#   'low_24h': 0.148136,
#   'price_change_24h': 0.00674077,
#   'price_change_percentage_24h': 4.54568,
#   'market_cap_change_24h': 250184439,
#   'market_cap_change_percentage_24h': 4.40856,
#   'circulating_supply': 38307972232.31476,
#   'total_supply': 38307972232.31476,
#   'max_supply': None,
#   'ath': 0.194152,
#   'ath_change_percentage': -20.30905,
#   'ath_date': '2026-02-03T08:02:08.411Z',
#   'atl': 0.059024,
#   'atl_change_percentage': 162.13264,
#   'atl_date': '2025-12-06T10:32:09.784Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.729Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 1.0,
#   'market_cap': 5829313274,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 5829313274,
#   'total_volume': 181309022,
#   'high_24h': 1.001,
#   'low_24h': 0.998774,
#   'price_change_24h': -1.4792420821363e-05,
#   'price_change_percentage_24h': -0.00148,
#   'market_cap_change_24h': 198579,
#   'market_cap_change_percentage_24h': 0.00341,
#   'circulating_supply': 5828297804.522167,
#   'total_supply': 5828297804.522167,
#   'max_supply': None,
#   'ath': 1.034,
#   'ath_change_percentage': -3.28009,
#   'ath_date': '2025-12-09T17:10:12.652Z',
#   'atl': 0.929486,
#   'atl_change_percentage': 7.59784,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.839Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 0.155845,
#   'market_cap': 5158705724,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 7792479907,
#   'total_volume': 89596157,
#   'high_24h': 0.156262,
#   'low_24h': 0.150567,
#   'price_change_24h': 0.0051108,
#   'price_change_percentage_24h': 3.39061,
#   'market_cap_change_24h': 169381211,
#   'market_cap_change_percentage_24h': 3.39487,
#   'circulating_supply': 33101722080.12213,
#   'total_supply': 50001786883.65895,
#   'max_supply': None,
#   'ath': 0.875563,
#   'ath_change_percentage': -82.19706,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 32638.56568,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:03.748Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'image': 'https://coin-images.coingecko.com/coins/images/53247/large/square-bg-transparent.png?1752637478',
#   'current_price': 2.86,
#   'market_cap': 5029256768,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 15331739241,
#   'total_volume': 18296318,
#   'high_24h': 2.99,
#   'low_24h': 2.7,
#   'price_change_24h': -0.021250931586135557,
#   'price_change_percentage_24h': -0.73777,
#   'market_cap_change_24h': -30776363.084568977,
#   'market_cap_change_percentage_24h': -0.60822,
#   'circulating_supply': 1757367397.62633,
#   'total_supply': 5357351977.545468,
#   'max_supply': 10000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -4.47766,
#   'ath_date': '2026-04-13T15:05:06.618Z',
#   'atl': 0.04746135,
#   'atl_change_percentage': 5914.81606,
#   'atl_date': '2025-07-04T03:56:17.448Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:07.468Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.999276,
#   'market_cap': 4371574445,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 4371574445,
#   'total_volume': 72711917,
#   'high_24h': 1.003,
#   'low_24h': 0.994766,
#   'price_change_24h': -0.001406624074213325,
#   'price_change_percentage_24h': -0.14057,
#   'market_cap_change_24h': -39029133.52383995,
#   'market_cap_change_percentage_24h': -0.88489,
#   'circulating_supply': 4373057122.357524,
#   'total_supply': 4373057122.357524,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -17.98627,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.34874,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:09.221Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 54.4,
#   'market_cap': 4191553685,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 4191677776,
#   'total_volume': 390403422,
#   'high_24h': 54.72,
#   'low_24h': 52.71,
#   'price_change_24h': 1.29,
#   'price_change_percentage_24h': 2.43161,
#   'market_cap_change_24h': 99461365,
#   'market_cap_change_percentage_24h': 2.43057,
#   'circulating_supply': 77056614.48347135,
#   'total_supply': 77058895.73347135,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -86.74837,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 4632.24999,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:04.778Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'image': 'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002',
#   'current_price': 0.999096,
#   'market_cap': 4094037677,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 4094037677,
#   'total_volume': 1521120813,
#   'high_24h': 0.999955,
#   'low_24h': 0.998656,
#   'price_change_24h': 2.801e-05,
#   'price_change_percentage_24h': 0.0028,
#   'market_cap_change_24h': -37813199.893773556,
#   'market_cap_change_percentage_24h': -0.91516,
#   'circulating_supply': 4097548054.591373,
#   'total_supply': 4097548054.591373,
#   'max_supply': None,
#   'ath': 1.025,
#   'ath_change_percentage': -2.52121,
#   'ath_date': '2025-05-12T12:36:39.412Z',
#   'atl': 0.989633,
#   'atl_change_percentage': 0.94533,
#   'atl_date': '2025-10-01T08:51:32.103Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:07.574Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 9.4,
#   'market_cap': 4058258842,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 4355919220,
#   'total_volume': 375040783,
#   'high_24h': 9.68,
#   'low_24h': 9.01,
#   'price_change_24h': 0.349888,
#   'price_change_percentage_24h': 3.8665,
#   'market_cap_change_24h': 152341570,
#   'market_cap_change_percentage_24h': 3.90028,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -93.51484,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 235.62127,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:12.114Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31212/large/PYUSD_Token_Logo_2x.png?1765987788',
#   'current_price': 0.999675,
#   'market_cap': 4026124567,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 4026124567,
#   'total_volume': 141665424,
#   'high_24h': 1.0,
#   'low_24h': 0.999454,
#   'price_change_24h': -0.000574284517213863,
#   'price_change_percentage_24h': -0.05741,
#   'market_cap_change_24h': 8711261,
#   'market_cap_change_percentage_24h': 0.21684,
#   'circulating_supply': 4027427526.398032,
#   'total_supply': 4027427526.398032,
#   'max_supply': None,
#   'ath': 1.081,
#   'ath_change_percentage': -7.49194,
#   'ath_date': '2026-04-02T07:35:31.426Z',
#   'atl': 0.959426,
#   'atl_change_percentage': 4.21543,
#   'atl_date': '2024-12-05T22:31:13.430Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.678Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'image': 'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191',
#   'current_price': 0.00806551,
#   'market_cap': 3858041865,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 9274190582,
#   'total_volume': 18372043,
#   'high_24h': 0.00819491,
#   'low_24h': 0.00761008,
#   'price_change_24h': 0.00012198,
#   'price_change_percentage_24h': 1.53554,
#   'market_cap_change_24h': 58600085,
#   'market_cap_change_percentage_24h': 1.54233,
#   'circulating_supply': 478357737544.77423,
#   'total_supply': 1149904790981.393,
#   'max_supply': 1150000000000.0,
#   'ath': 0.01090099,
#   'ath_change_percentage': -26.00433,
#   'ath_date': '2026-02-09T16:50:09.904Z',
#   'atl': 0.00222126,
#   'atl_change_percentage': 263.13902,
#   'atl_date': '2025-09-14T08:56:57.416Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.149Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.086505,
#   'market_cap': 3747548959,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 4325349341,
#   'total_volume': 82135837,
#   'high_24h': 0.087943,
#   'low_24h': 0.084512,
#   'price_change_24h': 0.00147858,
#   'price_change_percentage_24h': 1.73897,
#   'market_cap_change_24h': 64057903,
#   'market_cap_change_percentage_24h': 1.73905,
#   'circulating_supply': 43320766299.18106,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -84.79613,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 777.63794,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.379Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 0.945694,
#   'market_cap': 3737814794,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 9454710524,
#   'total_volume': 377081697,
#   'high_24h': 0.96054,
#   'low_24h': 0.899936,
#   'price_change_24h': 0.04458161,
#   'price_change_percentage_24h': 4.9474,
#   'market_cap_change_24h': 174910343,
#   'market_cap_change_percentage_24h': 4.90921,
#   'circulating_supply': 3953388932.071221,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 5.35,
#   'ath_change_percentage': -82.31212,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 0.364846,
#   'atl_change_percentage': 159.20345,
#   'atl_date': '2023-10-19T10:40:30.078Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.009Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 1.44,
#   'market_cap': 3563690872,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 7411964891,
#   'total_volume': 112550031,
#   'high_24h': 1.45,
#   'low_24h': 1.4,
#   'price_change_24h': 0.01990032,
#   'price_change_percentage_24h': 1.40468,
#   'market_cap_change_24h': 48338382,
#   'market_cap_change_percentage_24h': 1.37507,
#   'circulating_supply': 2482097138.690984,
#   'total_supply': 5162405357.601468,
#   'max_supply': None,
#   'ath': 8.25,
#   'ath_change_percentage': -82.62251,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 176.15899,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:04.994Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 5.9e-06,
#   'market_cap': 3473146124,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 3474658384,
#   'total_volume': 125692160,
#   'high_24h': 6e-06,
#   'low_24h': 5.75e-06,
#   'price_change_24h': 1.36411e-07,
#   'price_change_percentage_24h': 2.36839,
#   'market_cap_change_24h': 79789167,
#   'market_cap_change_percentage_24h': 2.35133,
#   'circulating_supply': 589243521383479.8,
#   'total_supply': 589500086857209.4,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -93.15674,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 10460157.16681,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:03.824Z'},
#  {'id': 'ravedao',
#   'symbol': 'rave',
#   'name': 'RaveDAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/70544/large/coin.jpeg?1762452940',
#   'current_price': 12.31,
#   'market_cap': 3058594111,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 12330830965,
#   'total_volume': 624039648,
#   'high_24h': 14.18,
#   'low_24h': 7.49,
#   'price_change_24h': 2.92,
#   'price_change_percentage_24h': 31.14535,
#   'market_cap_change_24h': 743196175,
#   'market_cap_change_percentage_24h': 32.09799,
#   'circulating_supply': 248044444.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 14.18,
#   'ath_change_percentage': -12.65159,
#   'ath_date': '2026-04-13T19:40:14.919Z',
#   'atl': 0.206266,
#   'atl_change_percentage': 5902.83213,
#   'atl_date': '2026-03-12T02:10:18.440Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.703Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 0.070647,
#   'market_cap': 2991914064,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 6962205080,
#   'total_volume': 13207198,
#   'high_24h': 0.07069,
#   'low_24h': 0.068147,
#   'price_change_24h': 0.00249912,
#   'price_change_percentage_24h': 3.66723,
#   'market_cap_change_24h': 102784261,
#   'market_cap_change_percentage_24h': 3.55762,
#   'circulating_supply': 42350915696.51784,
#   'total_supply': 98550878842.43558,
#   'max_supply': 100000000000.0,
#   'ath': 0.891544,
#   'ath_change_percentage': -92.08003,
#   'ath_date': '2021-11-24T00:00:00.000Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 482.61056,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.929Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'image': 'https://coin-images.coingecko.com/coins/images/51054/large/Hashnote_SDYC_200x200.png?1730370965',
#   'current_price': 1.12,
#   'market_cap': 2682492844,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 2682492844,
#   'total_volume': 112099,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 2392972188.222456,
#   'total_supply': 2392972188.222456,
#   'max_supply': None,
#   'ath': 1.12,
#   'ath_change_percentage': -0.09236,
#   'ath_date': '2026-04-08T14:31:05.529Z',
#   'atl': 1.026,
#   'atl_change_percentage': 9.24713,
#   'atl_date': '2024-12-05T22:31:20.475Z',
#   'roi': None,
#   'last_updated': '2026-04-09T23:06:04.591Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/10481/large/logo.png?1774627372',
#   'current_price': 4758.89,
#   'market_cap': 2662515852,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 3366789525,
#   'total_volume': 367484446,
#   'high_24h': 4768.1,
#   'low_24h': 4677.98,
#   'price_change_24h': 49.63,
#   'price_change_percentage_24h': 1.05395,
#   'market_cap_change_24h': 27000584,
#   'market_cap_change_percentage_24h': 1.02449,
#   'circulating_supply': 559698.736688,
#   'total_supply': 707747.089,
#   'max_supply': None,
#   'ath': 5504.62,
#   'ath_change_percentage': -13.59579,
#   'ath_date': '2026-01-29T00:00:00.000Z',
#   'atl': 1447.84,
#   'atl_change_percentage': 228.50424,
#   'atl_date': '2020-03-19T13:45:41.821Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:04.653Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 0.08062,
#   'market_cap': 2560545012,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 8061458326,
#   'total_volume': 73561182,
#   'high_24h': 0.082157,
#   'low_24h': 0.078735,
#   'price_change_24h': 0.00143979,
#   'price_change_percentage_24h': 1.81837,
#   'market_cap_change_24h': 44667602,
#   'market_cap_change_percentage_24h': 1.77543,
#   'circulating_supply': 31762801571.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.331336,
#   'ath_change_percentage': -75.66824,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 0.07726,
#   'atl_change_percentage': 4.3486,
#   'atl_date': '2026-04-11T07:56:04.528Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.623Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/36291/large/blackrock.png?1711013223',
#   'current_price': 1.0,
#   'market_cap': 2443379496,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 2443379496,
#   'total_volume': 0.0,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'circulating_supply': 2443379495.530449,
#   'total_supply': 2443379495.530449,
#   'max_supply': None,
#   'ath': 1.0,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2025-02-12T05:00:10.912Z',
#   'atl': 1.0,
#   'atl_change_percentage': 0.0,
#   'atl_date': '2025-02-12T05:45:10.196Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:25:17.330Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 253.22,
#   'market_cap': 2430042433,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 5317107470,
#   'total_volume': 276372518,
#   'high_24h': 263.69,
#   'low_24h': 251.72,
#   'price_change_24h': -6.031380422759952,
#   'price_change_percentage_24h': -2.32648,
#   'market_cap_change_24h': -59226689.90520334,
#   'market_cap_change_percentage_24h': -2.37928,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 757.6,
#   'ath_change_percentage': -66.58164,
#   'ath_date': '2024-03-07T18:45:36.466Z',
#   'atl': 30.83,
#   'atl_change_percentage': 721.21108,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.069Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/9519/large/paxgold.png?1696509604',
#   'current_price': 4767.8,
#   'market_cap': 2419410493,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 2419410493,
#   'total_volume': 297723778,
#   'high_24h': 4777.84,
#   'low_24h': 4688.85,
#   'price_change_24h': 52.66,
#   'price_change_percentage_24h': 1.11685,
#   'market_cap_change_24h': 26204787,
#   'market_cap_change_percentage_24h': 1.09497,
#   'circulating_supply': 507641.795,
#   'total_supply': 507641.795,
#   'max_supply': None,
#   'ath': 5619.09,
#   'ath_change_percentage': -15.19919,
#   'ath_date': '2026-01-29T06:30:56.612Z',
#   'atl': 1399.64,
#   'atl_change_percentage': 240.44676,
#   'atl_date': '2019-11-18T03:09:35.959Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:09.065Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/MNT_Token_Logo.png?1765516974',
#   'current_price': 0.682093,
#   'market_cap': 2235779618,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 4241994828,
#   'total_volume': 37723004,
#   'high_24h': 0.687403,
#   'low_24h': 0.661572,
#   'price_change_24h': 0.01896643,
#   'price_change_percentage_24h': 2.86015,
#   'market_cap_change_24h': 62026614,
#   'market_cap_change_percentage_24h': 2.85343,
#   'circulating_supply': 3277944055.53684,
#   'total_supply': 6219316794.889999,
#   'max_supply': 6219316794.89,
#   'ath': 2.86,
#   'ath_change_percentage': -76.17002,
#   'ath_date': '2025-10-09T01:04:46.659Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 120.91201,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.877Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/51281/large/GDN_USDG_Token_200x200.png?1730484111',
#   'current_price': 0.999781,
#   'market_cap': 2159285242,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 2159285242,
#   'total_volume': 86104646,
#   'high_24h': 1.0,
#   'low_24h': 0.999731,
#   'price_change_24h': -0.000147879086854541,
#   'price_change_percentage_24h': -0.01479,
#   'market_cap_change_24h': 57266875,
#   'market_cap_change_percentage_24h': 2.72438,
#   'circulating_supply': 2159590280.873684,
#   'total_supply': 2159590280.873684,
#   'max_supply': None,
#   'ath': 1.65,
#   'ath_change_percentage': -39.56991,
#   'ath_date': '2025-01-30T00:11:05.728Z',
#   'atl': 0.907561,
#   'atl_change_percentage': 10.16616,
#   'atl_date': '2024-11-11T23:55:50.604Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.659Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 3.18,
#   'market_cap': 2012399052,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 2849090739,
#   'total_volume': 213631534,
#   'high_24h': 3.25,
#   'low_24h': 3.01,
#   'price_change_24h': 0.138956,
#   'price_change_percentage_24h': 4.57216,
#   'market_cap_change_24h': 87273697,
#   'market_cap_change_percentage_24h': 4.5334,
#   'circulating_supply': 633561603.6037512,
#   'total_supply': 896976420.0366304,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -92.92881,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 208.32187,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.584Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.jpg?1766533446',
#   'current_price': 1.19,
#   'market_cap': 1994254886,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 1994254886,
#   'total_volume': 300464975,
#   'high_24h': 1.24,
#   'low_24h': 1.16,
#   'price_change_24h': -0.007765908700865687,
#   'price_change_percentage_24h': -0.6498,
#   'market_cap_change_24h': -7673240.09504962,
#   'market_cap_change_percentage_24h': -0.38329,
#   'circulating_supply': 1679150247.503485,
#   'total_supply': 1679150247.503485,
#   'max_supply': 2100000000.0,
#   'ath': 54.98,
#   'ath_change_percentage': -97.84061,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 1.15,
#   'atl_change_percentage': 3.2087,
#   'atl_date': '2026-02-06T00:25:45.413Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.065Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 1.43,
#   'market_cap': 1856122185,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 1856122189,
#   'total_volume': 237793521,
#   'high_24h': 1.44,
#   'low_24h': 1.37,
#   'price_change_24h': 0.04633946,
#   'price_change_percentage_24h': 3.33951,
#   'market_cap_change_24h': 58135861,
#   'market_cap_change_percentage_24h': 3.23339,
#   'circulating_supply': 1292812192.0,
#   'total_supply': 1292812195.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -92.97928,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 172.40058,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:03.726Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/54558/large/ff_200_X_200.png?1740741076',
#   'current_price': 0.998282,
#   'market_cap': 1786372913,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 1786372913,
#   'total_volume': 698699,
#   'high_24h': 0.998752,
#   'low_24h': 0.997451,
#   'price_change_24h': 0.00017263,
#   'price_change_percentage_24h': 0.0173,
#   'market_cap_change_24h': -17759.837833166122,
#   'market_cap_change_percentage_24h': -0.00099,
#   'circulating_supply': 1789549457.493094,
#   'total_supply': 1789549457.493094,
#   'max_supply': None,
#   'ath': 1.075,
#   'ath_change_percentage': -7.09967,
#   'ath_date': '2025-05-08T21:25:42.071Z',
#   'atl': 0.943422,
#   'atl_change_percentage': 5.81587,
#   'atl_date': '2025-07-08T10:16:34.749Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:07.098Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 84.92,
#   'market_cap': 1783231346,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 1783231346,
#   'total_volume': 15324120,
#   'high_24h': 84.97,
#   'low_24h': 82.62,
#   'price_change_24h': 2.21,
#   'price_change_percentage_24h': 2.66712,
#   'market_cap_change_24h': 46327558,
#   'market_cap_change_percentage_24h': 2.66725,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 228.74,
#   'ath_change_percentage': -62.86235,
#   'ath_date': '2025-10-05T00:00:00.000Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 14530.94557,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.432Z'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'image': 'https://coin-images.coingecko.com/coins/images/39925/large/sky.jpg?1724827980',
#   'current_price': 0.074236,
#   'market_cap': 1718873897,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 1741551040,
#   'total_volume': 11359425,
#   'high_24h': 0.076138,
#   'low_24h': 0.071613,
#   'price_change_24h': 0.0015967,
#   'price_change_percentage_24h': 2.19813,
#   'market_cap_change_24h': 36752211,
#   'market_cap_change_percentage_24h': 2.18487,
#   'circulating_supply': 23157152301.77788,
#   'total_supply': 23462665147.36596,
#   'max_supply': 23462665147.3,
#   'ath': 0.100535,
#   'ath_change_percentage': -26.20311,
#   'ath_date': '2024-12-04T10:13:57.264Z',
#   'atl': 0.03582727,
#   'atl_change_percentage': 107.08213,
#   'atl_date': '2025-02-03T05:01:48.626Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.521Z'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/54342/large/pi_network.jpg?1739347576',
#   'current_price': 0.165167,
#   'market_cap': 1675042854,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 2576989006,
#   'total_volume': 15099968,
#   'high_24h': 0.167071,
#   'low_24h': 0.164071,
#   'price_change_24h': -0.001370414144387266,
#   'price_change_percentage_24h': -0.82289,
#   'market_cap_change_24h': -13187616.545203924,
#   'market_cap_change_percentage_24h': -0.78115,
#   'circulating_supply': 10142200266.49829,
#   'total_supply': 15603385025.38199,
#   'max_supply': 100000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -94.47481,
#   'ath_date': '2025-02-26T16:41:03.732Z',
#   'atl': 0.131244,
#   'atl_change_percentage': 25.77439,
#   'atl_date': '2026-02-11T17:06:46.605Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.987Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 0.670462,
#   'market_cap': 1648198383,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 5244159722,
#   'total_volume': 127464666,
#   'high_24h': 0.682766,
#   'low_24h': 0.655771,
#   'price_change_24h': 0.01296196,
#   'price_change_percentage_24h': 1.9714,
#   'market_cap_change_24h': 30769137,
#   'market_cap_change_percentage_24h': 1.90235,
#   'circulating_supply': 2458559719.12999,
#   'total_supply': 7822529124.595041,
#   'max_supply': 8000000000.0,
#   'ath': 2.41,
#   'ath_change_percentage': -72.16539,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 0.099713,
#   'atl_change_percentage': 572.38871,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.220Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/35491/large/Frame_1321318576.png?1708908626',
#   'current_price': 1.77e-06,
#   'market_cap': 1624409909,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 1624409909,
#   'total_volume': 15534681,
#   'high_24h': 1.78e-06,
#   'low_24h': 1.77e-06,
#   'price_change_24h': -7.032993496e-09,
#   'price_change_percentage_24h': -0.39542,
#   'market_cap_change_24h': -5727847.834397316,
#   'market_cap_change_percentage_24h': -0.35137,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'max_supply': 999990000000000.0,
#   'ath': 3.75e-06,
#   'ath_change_percentage': -52.7786,
#   'ath_date': '2024-12-04T00:16:20.770Z',
#   'atl': 8.00816e-07,
#   'atl_change_percentage': 121.21302,
#   'atl_date': '2024-08-05T13:31:33.427Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.466Z'},
#  {'id': 'usdd',
#   'symbol': 'usdd',
#   'name': 'USDD',
#   'image': 'https://coin-images.coingecko.com/coins/images/25380/large/UUSD.jpg?1696524513',
#   'current_price': 1.0,
#   'market_cap': 1542446754,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 1543392879,
#   'total_volume': 4213378,
#   'high_24h': 1.001,
#   'low_24h': 0.999979,
#   'price_change_24h': 0.00044579,
#   'price_change_percentage_24h': 0.04458,
#   'market_cap_change_24h': 85438936,
#   'market_cap_change_percentage_24h': 5.864,
#   'circulating_supply': 1542243860.0,
#   'total_supply': 1543189861.0,
#   'max_supply': None,
#   'ath': 1.052,
#   'ath_change_percentage': -4.88389,
#   'ath_date': '2023-10-23T22:45:25.398Z',
#   'atl': 0.928067,
#   'atl_change_percentage': 7.79927,
#   'atl_date': '2022-06-19T16:15:11.558Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:04.872Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 3.65e-06,
#   'market_cap': 1536024249,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 1536024249,
#   'total_volume': 440197804,
#   'high_24h': 3.75e-06,
#   'low_24h': 3.46e-06,
#   'price_change_24h': 1.89442e-07,
#   'price_change_percentage_24h': 5.46692,
#   'market_cap_change_24h': 77710135,
#   'market_cap_change_percentage_24h': 5.32877,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 2.803e-05,
#   'ath_change_percentage': -86.96066,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 5.5142e-08,
#   'atl_change_percentage': 6527.73477,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.217Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 100.24,
#   'market_cap': 1518828950,
#   'market_cap_rank': 55,
#   'fully_diluted_valuation': 1602482421,
#   'total_volume': 332100749,
#   'high_24h': 103.82,
#   'low_24h': 93.42,
#   'price_change_24h': 5.24,
#   'price_change_percentage_24h': 5.5133,
#   'market_cap_change_24h': 78357723,
#   'market_cap_change_percentage_24h': 5.43973,
#   'circulating_supply': 15164761.178472267,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -84.88105,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 284.42933,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:12.170Z'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/39651/large/RLUSD_200x200_%281%29.png?1727376633',
#   'current_price': 0.999939,
#   'market_cap': 1441690807,
#   'market_cap_rank': 56,
#   'fully_diluted_valuation': 1441690807,
#   'total_volume': 140580815,
#   'high_24h': 1.001,
#   'low_24h': 0.999289,
#   'price_change_24h': 7.057e-05,
#   'price_change_percentage_24h': 0.00706,
#   'market_cap_change_24h': 20886241,
#   'market_cap_change_percentage_24h': 1.47003,
#   'circulating_supply': 1441761093.407244,
#   'total_supply': 1441761093.407244,
#   'max_supply': None,
#   'ath': 1.073,
#   'ath_change_percentage': -6.79033,
#   'ath_date': '2024-12-26T10:45:52.337Z',
#   'atl': 0.962292,
#   'atl_change_percentage': 3.91547,
#   'atl_date': '2024-12-18T04:40:40.880Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:06.717Z'},
#  {'id': 'janus-henderson-anemoy-treasury-fund',
#   'symbol': 'jtrsy',
#   'name': 'Janus Henderson Anemoy Treasury Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/70445/large/JTRSY.png?1762078582',
#   'current_price': 1.1,
#   'market_cap': 1372339867,
#   'market_cap_rank': 57,
#   'fully_diluted_valuation': 1372339867,
#   'total_volume': 0.0,
# ...
#   'total_volume': 12081.37,
#   'high_24h': 0.01238787,
#   'low_24h': 0.01143716,
#   'price_change_24h': 0.00061701,
#   'price_change_percentage_24h': 5.31965,
#   'market_cap_change_24h': 35518978,
#   'market_cap_change_percentage_24h': 5.39246,
#   'circulating_supply': 56828398966.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.060147,
#   'ath_change_percentage': -79.69021,
#   'ath_date': '2025-09-14T16:52:41.627Z',
#   'atl': 0.00940996,
#   'atl_change_percentage': 29.81685,
#   'atl_date': '2026-03-30T23:46:20.691Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:07.351Z'},
#  {'id': 'flare-networks',
#   'symbol': 'flr',
#   'name': 'Flare',
#   'image': 'https://coin-images.coingecko.com/coins/images/28624/large/FLR-icon200x200.png?1696527609',
#   'current_price': 0.00799845,
#   'market_cap': 685610954,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 844279272,
#   'total_volume': 3910191,
#   'high_24h': 0.00808978,
#   'low_24h': 0.00768648,
#   'price_change_24h': 0.00030567,
#   'price_change_percentage_24h': 3.97343,
#   'market_cap_change_24h': 26679580,
#   'market_cap_change_percentage_24h': 4.04892,
#   'circulating_supply': 85666021025.94635,
#   'total_supply': 105491380230.391,
#   'max_supply': None,
#   'ath': 0.150073,
#   'ath_change_percentage': -94.66746,
#   'ath_date': '2023-01-10T03:14:05.921Z',
#   'atl': 0.00726058,
#   'atl_change_percentage': 10.22123,
#   'atl_date': '2026-04-07T18:55:08.564Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.403Z'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'image': 'https://coin-images.coingecko.com/coins/images/16547/large/arb.jpg?1721358242',
#   'current_price': 0.113063,
#   'market_cap': 682914004,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 1130498070,
#   'total_volume': 72905220,
#   'high_24h': 0.113613,
#   'low_24h': 0.110394,
#   'price_change_24h': 0.0022119,
#   'price_change_percentage_24h': 1.99539,
#   'market_cap_change_24h': 13420177,
#   'market_cap_change_percentage_24h': 2.00453,
#   'circulating_supply': 6040824145.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.39,
#   'ath_change_percentage': -95.27968,
#   'ath_date': '2024-01-12T12:29:59.231Z',
#   'atl': 0.087087,
#   'atl_change_percentage': 29.55886,
#   'atl_date': '2026-03-29T22:50:51.753Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:04.402Z'},
#  {'id': 'just',
#   'symbol': 'jst',
#   'name': 'JUST',
#   'image': 'https://coin-images.coingecko.com/coins/images/11095/large/JUST.jpg?1696511035',
#   'current_price': 0.077412,
#   'market_cap': 681676460,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 681676460,
#   'total_volume': 48456602,
#   'high_24h': 0.080784,
#   'low_24h': 0.074987,
#   'price_change_24h': -0.00082154096982763,
#   'price_change_percentage_24h': -1.05011,
#   'market_cap_change_24h': -9472852.046433687,
#   'market_cap_change_percentage_24h': -1.37059,
#   'circulating_supply': 8815108920.581306,
#   'total_supply': 8815108920.581306,
#   'max_supply': 9900000000.0,
#   'ath': 0.193254,
#   'ath_change_percentage': -60.0763,
#   'ath_date': '2021-04-05T04:34:23.454Z',
#   'atl': 0.00476275,
#   'atl_change_percentage': 1519.95169,
#   'atl_date': '2020-05-09T06:08:54.872Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:03.628Z'},
#  {'id': 'ousg',
#   'symbol': 'ousg',
#   'name': 'OUSG',
#   'image': 'https://coin-images.coingecko.com/coins/images/29023/large/OUSG.png?1696527993',
#   'current_price': 114.91,
#   'market_cap': 674946796,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 674946796,
#   'total_volume': 0.0,
#   'high_24h': 114.91,
#   'low_24h': 114.87,
#   'price_change_24h': 0.035831,
#   'price_change_percentage_24h': 0.03119,
#   'market_cap_change_24h': -1689216.58009243,
#   'market_cap_change_percentage_24h': -0.24965,
#   'circulating_supply': 5873670.758358905,
#   'total_supply': 5873670.758358905,
#   'max_supply': None,
#   'ath': 114.91,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2026-04-13T21:15:07.634Z',
#   'atl': 95.09,
#   'atl_change_percentage': 20.84325,
#   'atl_date': '2023-03-22T20:00:17.106Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:20:03.990Z'},
#  {'id': 'official-trump',
#   'symbol': 'trump',
#   'name': 'Official Trump',
#   'image': 'https://coin-images.coingecko.com/coins/images/53746/large/trump.png?1737171561',
#   'current_price': 2.83,
#   'market_cap': 658693698,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 2833105706,
#   'total_volume': 98927942,
#   'high_24h': 2.88,
#   'low_24h': 2.8,
#   'price_change_24h': 0.0330049,
#   'price_change_percentage_24h': 1.1785,
#   'market_cap_change_24h': 7614333,
#   'market_cap_change_percentage_24h': 1.16949,
#   'circulating_supply': 232498807.465716,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 73.43,
#   'ath_change_percentage': -96.14447,
#   'ath_date': '2025-01-19T11:50:34.806Z',
#   'atl': 2.73,
#   'atl_change_percentage': 3.69943,
#   'atl_date': '2026-03-12T14:42:04.966Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:07.137Z'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/2912/large/xdc-icon.png?1696503661',
#   'current_price': 0.03114929,
#   'market_cap': 621229714,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 1185656638,
#   'total_volume': 26727231,
#   'high_24h': 0.03151569,
#   'low_24h': 0.03023433,
#   'price_change_24h': 0.00041471,
#   'price_change_percentage_24h': 1.34934,
#   'market_cap_change_24h': 8339706,
#   'market_cap_change_percentage_24h': 1.36072,
#   'circulating_supply': 19942478754.87,
#   'total_supply': 38061496036.35,
#   'max_supply': None,
#   'ath': 0.192754,
#   'ath_change_percentage': -83.83021,
#   'ath_date': '2021-08-21T04:39:48.324Z',
#   'atl': 0.00039532,
#   'atl_change_percentage': 7784.27089,
#   'atl_date': '2019-07-22T00:00:00.000Z',
#   'roi': {'times': 0.7411314703405478,
#    'currency': 'eth',
#    'percentage': 74.11314703405479},
#   'last_updated': '2026-04-14T08:30:05.521Z'},
#  {'id': 'beldex',
#   'symbol': 'bdx',
#   'name': 'Beldex',
#   'image': 'https://coin-images.coingecko.com/coins/images/5111/large/Beldex.png?1696505631',
#   'current_price': 0.08026,
#   'market_cap': 620975764,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 797506235,
#   'total_volume': 12721552,
#   'high_24h': 0.080605,
#   'low_24h': 0.080073,
#   'price_change_24h': 0.00014361,
#   'price_change_percentage_24h': 0.17925,
#   'market_cap_change_24h': 919787,
#   'market_cap_change_percentage_24h': 0.14834,
#   'circulating_supply': 7737532156.648905,
#   'total_supply': 9937151327.331675,
#   'max_supply': None,
#   'ath': 0.450785,
#   'ath_change_percentage': -82.19983,
#   'ath_date': '2018-12-17T00:00:00.000Z',
#   'atl': 0.00027519,
#   'atl_change_percentage': 29058.68001,
#   'atl_date': '2019-11-01T11:05:12.090Z',
#   'roi': {'times': -0.6789610778901276,
#    'currency': 'usd',
#    'percentage': -67.89610778901276},
#   'last_updated': '2026-04-14T08:30:06.506Z'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'image': 'https://coin-images.coingecko.com/coins/images/1167/large/VET.png?1742383283',
#   'current_price': 0.00700779,
#   'market_cap': 602520410,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 602520410,
#   'total_volume': 16004268,
#   'high_24h': 0.00709747,
#   'low_24h': 0.00670797,
#   'price_change_24h': 0.00029807,
#   'price_change_percentage_24h': 4.44235,
#   'market_cap_change_24h': 25573457,
#   'market_cap_change_percentage_24h': 4.43255,
#   'circulating_supply': 85985041177.0,
#   'total_supply': 85985041177.0,
#   'max_supply': 86712634466.0,
#   'ath': 0.280991,
#   'ath_change_percentage': -97.50628,
#   'ath_date': '2021-04-19T01:08:21.675Z',
#   'atl': 0.00191713,
#   'atl_change_percentage': 265.5002,
#   'atl_date': '2020-03-13T02:29:59.652Z',
#   'roi': {'times': 0.0309802029452219,
#    'currency': 'eth',
#    'percentage': 3.09802029452219},
#   'last_updated': '2026-04-14T08:30:07.792Z'},
#  {'id': 'jupiter-exchange-solana',
#   'symbol': 'jup',
#   'name': 'Jupiter',
#   'image': 'https://coin-images.coingecko.com/coins/images/34188/large/jup.png?1704266489',
#   'current_price': 0.168872,
#   'market_cap': 599631299,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 1159123917,
#   'total_volume': 22480982,
#   'high_24h': 0.171375,
#   'low_24h': 0.162269,
#   'price_change_24h': 0.00578324,
#   'price_change_percentage_24h': 3.54606,
#   'market_cap_change_24h': 20498552,
#   'market_cap_change_percentage_24h': 3.53953,
#   'circulating_supply': 3550835739.32,
#   'total_supply': 6863982317.534854,
#   'max_supply': 10000000000.0,
#   'ath': 2.0,
#   'ath_change_percentage': -91.56815,
#   'ath_date': '2024-01-31T15:02:47.304Z',
#   'atl': 0.135801,
#   'atl_change_percentage': 24.18035,
#   'atl_date': '2026-02-12T18:35:44.925Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.801Z'},
#  {'id': 'midnight-3',
#   'symbol': 'night',
#   'name': 'Midnight',
#   'image': 'https://coin-images.coingecko.com/coins/images/71015/large/midnight.png?1765193080',
#   'current_price': 0.03573329,
#   'market_cap': 593467190,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 857642561,
#   'total_volume': 36299045,
#   'high_24h': 0.03945195,
#   'low_24h': 0.03547311,
#   'price_change_24h': -0.003457467727127829,
#   'price_change_percentage_24h': -8.82215,
#   'market_cap_change_24h': -57240225.69569051,
#   'market_cap_change_percentage_24h': -8.79661,
#   'circulating_supply': 16607399400.63495,
#   'total_supply': 24000000000.0,
#   'max_supply': 24000000000.0,
#   'ath': 0.118529,
#   'ath_change_percentage': -69.82857,
#   'ath_date': '2025-12-09T09:29:38.386Z',
#   'atl': 0.02378032,
#   'atl_change_percentage': 50.38443,
#   'atl_date': '2025-12-09T09:48:36.670Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.689Z'},
#  {'id': 'gho',
#   'symbol': 'gho',
#   'name': 'GHO',
#   'image': 'https://coin-images.coingecko.com/coins/images/30663/large/gho-token-logo.png?1720517092',
#   'current_price': 0.999541,
#   'market_cap': 583726939,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 583726939,
#   'total_volume': 6648538,
#   'high_24h': 1.0,
#   'low_24h': 0.999051,
#   'price_change_24h': 8.78e-06,
#   'price_change_percentage_24h': 0.00088,
#   'market_cap_change_24h': -15968.43758893013,
#   'market_cap_change_percentage_24h': -0.00274,
#   'circulating_supply': 584000000.0,
#   'total_supply': 584000000.0,
#   'max_supply': None,
#   'ath': 1.03,
#   'ath_change_percentage': -2.94028,
#   'ath_date': '2024-02-28T17:15:58.387Z',
#   'atl': 0.917065,
#   'atl_change_percentage': 8.99572,
#   'atl_date': '2023-10-24T04:41:04.568Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.288Z'},
#  {'id': 'ylds',
#   'symbol': 'ylds',
#   'name': 'YLDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/66486/large/YLDS.png?1772560579',
#   'current_price': 0.999731,
#   'market_cap': 578156879,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 578156879,
#   'total_volume': 2107967,
#   'high_24h': 0.999931,
#   'low_24h': 0.999707,
#   'price_change_24h': -0.000189931836454327,
#   'price_change_percentage_24h': -0.01899,
#   'market_cap_change_24h': -22991617.390226364,
#   'market_cap_change_percentage_24h': -3.82462,
#   'circulating_supply': 578312365.69,
#   'total_supply': 578312365.69,
#   'max_supply': None,
#   'ath': 1.001,
#   'ath_change_percentage': -0.13538,
#   'ath_date': '2026-02-13T15:00:58.249Z',
#   'atl': 0.999202,
#   'atl_change_percentage': 0.05283,
#   'atl_date': '2025-11-16T12:26:29.488Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:07.696Z'},
#  {'id': 'stable-2',
#   'symbol': 'stable',
#   'name': '\u200b\u200bStable',
#   'image': 'https://coin-images.coingecko.com/coins/images/69242/large/stable-logotype-framed-square-light.png?1762753913',
#   'current_price': 0.02641577,
#   'market_cap': 573778747,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 2635282243,
#   'total_volume': 47246878,
#   'high_24h': 0.03075438,
#   'low_24h': 0.02531759,
#   'price_change_24h': -0.002867350311994012,
#   'price_change_percentage_24h': -9.79182,
#   'market_cap_change_24h': -62926954.47555208,
#   'market_cap_change_percentage_24h': -9.88321,
#   'circulating_supply': 21772952331.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.0388874,
#   'ath_change_percentage': -32.35621,
#   'ath_date': '2026-02-27T01:55:43.571Z',
#   'atl': 0.0092214,
#   'atl_change_percentage': 185.25944,
#   'atl_date': '2025-12-24T05:49:32.232Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:08.813Z'},
#  {'id': 'usual-usd',
#   'symbol': 'usd0',
#   'name': 'Usual USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/38272/large/USD0LOGO.png?1716962811',
#   'current_price': 0.99814,
#   'market_cap': 557818397,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 557818397,
#   'total_volume': 523978,
#   'high_24h': 1.001,
#   'low_24h': 0.992426,
#   'price_change_24h': -0.00249846810904486,
#   'price_change_percentage_24h': -0.24969,
#   'market_cap_change_24h': -1654969.241061926,
#   'market_cap_change_percentage_24h': -0.29581,
#   'circulating_supply': 558894364.9639908,
#   'total_supply': 558894364.9639908,
#   'max_supply': None,
#   'ath': 1.33,
#   'ath_change_percentage': -24.69918,
#   'ath_date': '2024-07-12T08:28:59.311Z',
#   'atl': 0.962885,
#   'atl_change_percentage': 3.67414,
#   'atl_date': '2025-04-10T08:30:51.088Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.894Z'},
#  {'id': 'siren-2',
#   'symbol': 'siren',
#   'name': 'Siren',
#   'image': 'https://coin-images.coingecko.com/coins/images/54479/large/siren.png?1739960056',
#   'current_price': 0.766018,
#   'market_cap': 557010177,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 557010177,
#   'total_volume': 17643939,
#   'high_24h': 0.812821,
#   'low_24h': 0.726726,
#   'price_change_24h': -0.01936095072404731,
#   'price_change_percentage_24h': -2.46517,
#   'market_cap_change_24h': -13852126.494575024,
#   'market_cap_change_percentage_24h': -2.42653,
#   'circulating_supply': 727274305.0434376,
#   'total_supply': 727274305.0434376,
#   'max_supply': 1000000000.0,
#   'ath': 3.61,
#   'ath_change_percentage': -78.66206,
#   'ath_date': '2026-03-22T17:26:33.134Z',
#   'atl': 0.02634736,
#   'atl_change_percentage': 2819.66232,
#   'atl_date': '2025-03-11T06:21:52.561Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:07.093Z'},
#  {'id': 'fetch-ai',
#   'symbol': 'fet',
#   'name': 'Artificial Superintelligence Alliance',
#   'image': 'https://coin-images.coingecko.com/coins/images/5681/large/ASI.png?1719827289',
#   'current_price': 0.236539,
#   'market_cap': 534331367,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 642104856,
#   'total_volume': 81707803,
#   'high_24h': 0.23996,
#   'low_24h': 0.226729,
#   'price_change_24h': 0.00734019,
#   'price_change_percentage_24h': 3.20254,
#   'market_cap_change_24h': 16523793,
#   'market_cap_change_percentage_24h': 3.19111,
#   'circulating_supply': 2258791208.4351873,
#   'total_supply': 2714384546.672,
#   'max_supply': 2714384546.672,
#   'ath': 3.45,
#   'ath_change_percentage': -93.10992,
#   'ath_date': '2024-03-28T17:21:18.050Z',
#   'atl': 0.00816959,
#   'atl_change_percentage': 2813.16312,
#   'atl_date': '2020-03-13T02:24:18.347Z',
#   'roi': {'times': 1.7282510287740405,
#    'currency': 'usd',
#    'percentage': 172.82510287740405},
#   'last_updated': '2026-04-14T08:30:07.653Z'},
#  {'id': 'bonk',
#   'symbol': 'bonk',
#   'name': 'Bonk',
#   'image': 'https://coin-images.coingecko.com/coins/images/28600/large/bonk.jpg?1696527587',
#   'current_price': 5.9e-06,
#   'market_cap': 518679375,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': 518679375,
#   'total_volume': 69569895,
#   'high_24h': 6.14e-06,
#   'low_24h': 5.61e-06,
#   'price_change_24h': 2.73545e-07,
#   'price_change_percentage_24h': 4.86528,
#   'market_cap_change_24h': 23830225,
#   'market_cap_change_percentage_24h': 4.81565,
#   'circulating_supply': 87994740501284.73,
#   'total_supply': 87994740501285.75,
#   'max_supply': 87995282867000.55,
#   'ath': 5.825e-05,
#   'ath_change_percentage': -89.88077,
#   'ath_date': '2024-11-20T04:01:06.465Z',
#   'atl': 8.6142e-08,
#   'atl_change_percentage': 6742.69769,
#   'atl_date': '2022-12-29T22:48:46.755Z',
#   'roi': None,
#   'last_updated': '2026-04-14T08:30:05.113Z'}]

# %%
# get_market_chart() 응답 내용(JSON) 확인
market_caps
# Out:
# [[1744675200000, 60199908506.245766],
#  [1744761600000, 60417188776.17674],
#  [1744848000000, 60482834985.68738],
#  [1744934400000, 60905068137.7922],
#  [1745020800000, 60899531624.784546],
#  [1745107200000, 60905279546.47661],
#  [1745193600000, 60912555306.20599],
#  [1745280000000, 60928832833.85901],
#  [1745366400000, 61589269101.35528],
#  [1745452800000, 61896921299.12466],
#  [1745539200000, 62129850660.586266],
#  [1745625600000, 62325968054.99818],
#  [1745712000000, 62251662906.80433],
#  [1745798400000, 62076749988.76833],
#  [1745884800000, 62026261648.921],
#  [1745971200000, 62142665088.87474],
#  [1746057600000, 61508869555.16433],
#  [1746144000000, 61469063386.18792],
#  [1746230400000, 61520122153.8279],
#  [1746316800000, 61504588129.61178],
#  [1746403200000, 61502292587.1267],
#  [1746489600000, 61786628299.92093],
#  [1746576000000, 60949351180.20576],
#  [1746662400000, 60947364928.44116],
#  [1746748800000, 60867341067.19171],
#  [1746835200000, 60689997043.40309],
#  [1746921600000, 60800003218.424],
#  [1747008000000, 60801300532.30528],
#  [1747094400000, 60886438189.638725],
#  [1747180800000, 60861380673.33633],
#  [1747267200000, 60631968614.49602],
#  [1747353600000, 60575195332.76094],
#  [1747440000000, 60805371271.162575],
#  [1747526400000, 60894170790.318344],
#  [1747612800000, 60855229769.997635],
#  [1747699200000, 60617499885.70176],
#  [1747785600000, 60660002910.37936],
#  [1747872000000, 61178036077.039345],
#  [1747958400000, 61212203672.456055],
#  [1748044800000, 61723721871.26919],
#  [1748131200000, 61721143708.71242],
#  [1748217600000, 61701492712.77306],
#  [1748304000000, 61543750452.91037],
#  [1748390400000, 61392676922.02948],
